# %%
# !pip3 install seaborn
# !pip3 install scipy

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt
import seaborn as sb
import scipy

# %%
# import data
my_df = pd.read_csv("/Users/sidrah/Downloads/onlinedeliverydata.csv")

# %%
my_df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#           Medium (P1)   Medium (P2)   Meal(P1) Meal(P2)  \
# 0  Food delivery apps   Web browser  Breakfast    Lunch
# 1  Food delivery apps   Web browser     Snacks   Dinner
# ...

# %%
sb.heatmap(my_df.isnull())
# Out:
# <Axes: >

# %%
my_df = my_df.dropna()
my_df.head
# Out:
# <bound method NDFrame.head of      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# ...

# %%
my_df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#           Medium (P1)   Medium (P2)   Meal(P1) Meal(P2)  \
# 0  Food delivery apps   Web browser  Breakfast    Lunch
# 1  Food delivery apps   Web browser     Snacks   Dinner
# ...

# %%
data=my_df

# %%
data["Gender"] = data["Gender"].map({"Male":0,"Female":1}) # male or female

data["Marital Status"] = data["Marital Status"].map({"Married":0,"Single":1,"Prefer not to say":2})


data["Occupation"] = data["Occupation"].replace(to_replace=["Employee","Self Employeed"], value=1) # employed
data["Occupation"] = data["Occupation"].replace(to_replace=["Student","House wife"], value=0) # unemployed


data["Educational Qualifications"] = data["Educational Qualifications"].map({"Graduate": 1, 
                                                                             "Post Graduate": 2, 
                                                                             "Ph.D": 3, "School": 4,
                                                                             "Uneducated": 5})


data["Monthly Income"] = data["Monthly Income"].replace(to_replace=["No Income"], value=0) # no income
data["Monthly Income"] = data["Monthly Income"].replace(to_replace=["Below Rs.10000",
                                                                   "More than 50000",
                                                                   "25001 to 50000",
                                                                   "10001 to 25000"], value=1)  # has an income
                                                                             
#data["Feedback"] = data["Feedback"].map({"Negative ":0,"Positive":1}) # negative or positive

data["Output"] = data["Output"].map({"No":0,"Yes":1}) # no or yes

# %%
for col in data.columns:
    data[col] = data[col].replace({'Agree': '1', 'Strongly agree': '1','Strongly Agree': '1','Neutral': '0','Strongly disagree': '2','Disagree': '2'})
    data[col] = data[col].replace({'Moderately Important': '1', 'Very Important': '1','Important': '1','Unimportant': '0','Slightly Important': '0'})
    data[col] = data[col].replace({'30 minutes': '30', '45 minutes': '45','60 minutes': '60','15 minutes': '15','More than 60 minutes': '70'})

# %%
print(data.columns)
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Medium (P1)', 'Medium (P2)', 'Meal(P1)', 'Meal(P2)',
#        'Perference(P1)', 'Perference(P2)', 'Ease and convenient',
#        'Time saving', 'More restaurant choices', 'Easy Payment option',
#        'More Offers and Discount', 'Good Food quality', 'Good Tracking system',
#        'Self Cooking', 'Health Concern', 'Late Delivery', 'Poor Hygiene',
#        'Bad past experience', 'Unavailability', 'Unaffordable',
#        'Long delivery time', 'Delay of delivery person getting assigned',
#        'Delay of delivery person picking up food', 'Wrong order delivered',
#        'Missing item', 'Order placed by mistake', 'Influence of time',
#        'Order Time', 'Maximum wait time', 'Residence in busy location',
#        'Google Maps Accuracy', 'Good Road Condition', 'Low quantity low time',
# ...

# %%
data.drop(['Influence of rating','Reviews','Influence of time','Perference(P2)','Perference(P1)','Medium (P1)','Medium (P2)','Meal(P1)','Meal(P2)','Pin code','latitude','longitude','Order Time'], axis=1, inplace=True)

# %%
pd.set_option('display.max_columns', None)
data.head(10)
data = data.astype(int)
data.dtypes
i = 0
for col in data.columns:
    i +=1
print(i)
# Out:
# 42

# %%
correlation_matrix=data.corr().round(2)
sb.heatmap(data=correlation_matrix, square=True, annot=False, yticklabels=False,)

plt.show()

# %%
correlation_matrix=data1.corr().round(2)
sb.heatmap(data=correlation_matrix)

plt.show()

# %%
# Assuming you have a DataFrame with many columns
# original_df = pd.read_csv('your_data.csv')

# Get the total number of columns in the original DataFrame
num_columns = len(data.columns)

# Specify the maximum number of columns per split DataFrame
max_columns_per_split = 11

# Initialize a list to store the split DataFrames
split_dfs = []

# Iterate through the original DataFrame's columns and create splits
for i in range(0, num_columns, max_columns_per_split):
    # Calculate the column range for the current split
    start_idx = i
    end_idx = min(i + max_columns_per_split, num_columns)
    
    # Extract the columns for the current split
    split_columns = data.iloc[:, start_idx:end_idx]
    
    # Create a new DataFrame for the split
    split_df = pd.DataFrame(split_columns)

    split_df['Output'] = data['Output']
    
    # Append the split DataFrame to the list
    split_dfs.append(split_df)

# The split_dfs list now contains DataFrames with a maximum of 10 columns each

# %%
print(split_dfs[1].columns)
# Out:
# Index(['More Offers and Discount', 'Good Food quality', 'Good Tracking system',
#        'Self Cooking', 'Health Concern', 'Late Delivery', 'Poor Hygiene',
#        'Bad past experience', 'Unavailability', 'Unaffordable',
#        'Long delivery time', 'Output'],
#       dtype='object')

# %%
correlation_matrix=split_dfs[0].corr().round(2)
sb.heatmap(data=correlation_matrix, annot=True)

plt.show()

# %%
correlation_matrix=split_dfs[1].corr().round(2)
sb.heatmap(data=correlation_matrix, annot=True)

plt.show()

# %%
correlation_matrix=split_dfs[2].corr().round(2)
sb.heatmap(data=correlation_matrix, annot=True)

plt.show()

# %%
correlation_matrix=split_dfs[3].corr().round(2)
sb.heatmap(data=correlation_matrix, annot=True)

plt.show()

# %%
ft = pd.crosstab(data['Ease and convenient'], data['Output'])
nft = ft.div(ft.sum(axis=1), axis=0)
# Change the label of output col from 0 to no and 1 to yes
# change the lable for wrong order delivered from 0 to neutral, 1 to agreed, 2 to disagreed
# data['Wrong order delivered'] = data['Wrong order delivered'].map({0: 'neutral', 1: 'agreed', 2: 'disagreed'})
sb.heatmap(nft, annot=True, fmt='g')
# Out:
# <Axes: xlabel='Output', ylabel='Ease and convenient'>

# %%
data.drop(['Gender','Educational Qualifications', 'Family size',
       'Self Cooking', 'Health Concern', 'Late Delivery', 'Poor Hygiene',
       'Bad past experience', 'Unavailability', 'Unaffordable',
       'Long delivery time', 'Delay of delivery person picking up food', 
       
       'Missing item', 'Order placed by mistake', 
       'Residence in busy location', 'Google Maps Accuracy',
       'Good Road Condition', 'Low quantity low time',
       'Delivery person ability', 'Less Delivery time',
       
       'Freshness ', 'Temperature', 'Good Taste ', 'Good Quantity','High Quality of package','Wrong order delivered'], axis=1,inplace=True)

# %%
print (data.columns)
# Out:
# Index(['Age', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Ease and convenient', 'Time saving', 'More restaurant choices',
#        'Easy Payment option', 'More Offers and Discount', 'Good Food quality',
#        'Good Tracking system', 'Delay of delivery person getting assigned',
#        'Maximum wait time', 'Number of calls', 'Politeness', 'Output'],
#       dtype='object')

# %%
correlation_matrix=data.corr().round(1)
sb.heatmap(data=correlation_matrix, annot=True)

plt.show()

# %%
# !pip3 install scikit-learn
from sklearn.model_selection import train_test_split

X = data.drop('Output',axis=1)
y = data['Output']

X_train,X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, 
                                                    random_state=101)

print("Shape of train dataset : ", X_train.shape)
print("Shape of test dataset : ", X_test.shape)
# Out:
# ...
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/db/0d/1f6d2cd52c886707b00ddb7ed2504cbf10903a60a7bebcd71f0f77d53505/scikit_learn-1.3.1-cp311-cp311-macosx_12_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for joblib>=1.1.1 from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for threadpoolctl>=2.0.0 from https://files.pythonhosted.org/packages/81/12/fd4dea011af9d69e1cad05c75f3f7202cdcbeac9b712eea58ca779a72865/threadpoolctl-3.2.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 15.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 13.5 MB/s eta 0:00:00
# ...
# Shape of train dataset :  (309, 15)
# Shape of test dataset :  (78, 15)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100)

rfc.fit(X_train, y_train)

print(rfc.score(X_test, y_test))
# Out:
# 0.9358974358974359

# %%
from sklearn.metrics import confusion_matrix
pred = rfc.predict(X_test)

print(confusion_matrix(pred,y_test))

plt.figure(figsize=(10,8))
sns.heatmap(confusion_matrix(pred,y_test), annot=True);
# Out:
# [[21  0]
#  [ 5 52]]

# %%
# Evaluating a score by cross-validation
# cv determines the cross-validation splitting strategy
from sklearn.model_selection import cross_val_score
scores = cross_val_score(rfc, X_train, y_train,cv=5)

# average score
print("Accuracy: ", scores.mean(), scores.std() * 2)
# Out:
# Accuracy:  0.9222104706504494 0.0390188002266314

# %%
import random 
r = random.randint(0,len(data))
print(r)
new_customer = data.drop('Output', axis=1).iloc[r]
new_customer
# Out:
# 83
# Age                                          22
# Marital Status                                1
# Occupation                                    0
# Monthly Income                                0
# Ease and convenient                           1
# Time saving                                   1
# More restaurant choices                       0
# Easy Payment option                           0
# More Offers and Discount                      1
# Good Food quality                             0
# Good Tracking system                          1
# Delay of delivery person getting assigned     0
# Maximum wait time                            60
# Number of calls                               0
# Politeness                                    1
# Name: 83, dtype: int64

# %%
rfc.predict(new_customer.values.reshape(1,15)) # predicted output
# data.iloc[r]['Output'] # actual Output
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
data.iloc[r]['Output'] # actual Output
# Out:
# 1

# %%
import pickle
pickle.dump(rfc, open('model.pkl','wb'))
